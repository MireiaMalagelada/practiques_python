# %% [markdown]
# ## Random numbers ##

# %%
import numpy as np

# %%
a=np.random.uniform(-1.0,1.0)  # el random pot ser uniforme (amb una distribucio uniforme)
print(a)
# Out:
# 0.8523646725065253

# %%
a=np.random.uniform(-1.0,1.0)  # el random pot ser uniforme (amb una distribucio uniforme)
print(a)
# Out:
# -0.8794401318887912

# %%
a=np.random.uniform(-1.0,1.0)  # el random pot ser uniforme (amb una distribucio uniforme)
print(a)
# Out:
# -0.69393246580965

# %%
# nums enters
e=np.random.randint(1,6)
print(e)
# Out:
# 5

# %%
# nums enters
e=np.random.randint(1,6)
print(e)
# Out:
# 3

# %%
# nums enters
e=np.random.randint(1,6)
print(e)
# Out:
# 1

# %% [markdown]
# no es completament random, pero serveix

# %% [markdown]
# ### calcula el num pi ###
# es pot fer calculant una area, qualsevol
# anem a github (monte_carlo_example)
