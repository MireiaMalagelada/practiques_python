# %% [markdown]
# ## Exemples comandes python ##

# %%
a = input("Entra un numero")
# Out:
# Entra un numero 4.5

# %%
b=a/3.0
print(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 b=a/3.0
#       2 print(b)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'

# %% [markdown]
# Es creu que es un string i no un float

# %%
a=float(input("Entra un numero"))
# Out:
# Entra un numero 4.5

# %%
b=a/3.0
print(b)
# Out:
# 1.5
